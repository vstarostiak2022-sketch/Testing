# %%
from datetime import datetime
name = "Vadim"
location = "Lviv"

print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Vadim start programming at 2025-10-21 19:50:41.633292. Lviv is the best city!
